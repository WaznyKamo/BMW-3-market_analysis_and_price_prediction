# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
from IPython.core.display import display, HTML
plt.rcParams.update({'figure.max_open_warning': 0})
display(HTML("<style>.container { width:80% !important; }</style>"))
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:80% !important; }</style>

# %%
file_path = r"C:\Users\Kamil\OneDrive\Inżynieria danych i Data Science\BMW-3-market_analysis_and_price_prediction\data\BMW3_data.csv"

data = pd.read_csv(file_path)
data.head()
# Out:
#                                  Nazwa    Cena Oferta od  \
# 0                     BMW Seria 3 330d  21 900  Prywatne
# 1          BMW Seria 3 328i Sport Line  77 600  Prywatne
# 2  BMW Seria 3 320d xDrive Luxury Line  29 999  Prywatne
# 3     BMW Seria 3 330d Touring M Sport  69 900  Prywatne
# 4                          BMW Seria 3  58 500  Prywatne
#
#   Pokaż oferty z numerem VIN Ma numer rejestracyjny Marka pojazdu  \
# 0                        Tak                    Tak           BMW
# 1                        Tak                    Tak           BMW
# 2                        Tak                    Tak           BMW
# 3                        Tak                    NaN           BMW
# 4                        Tak                    Tak           BMW
#
#   Model pojazdu                   Wersja                    Generacja  \
# 0       Seria 3                     330d              E46 (1998-2007)
# 1       Seria 3          328i Sport Line          F30/F31 (2012-2020)
# ...

# %%
data.columns
# Out:
# Index(['Nazwa', 'Cena', 'Oferta od', 'Pokaż oferty z numerem VIN',
#        'Ma numer rejestracyjny', 'Marka pojazdu', 'Model pojazdu', 'Wersja',
#        'Generacja', 'Rok produkcji', 'Przebieg', 'Pojemność skokowa',
#        'Rodzaj paliwa', 'Moc', 'Skrzynia biegów', 'Napęd',
#        'Spalanie Poza Miastem', 'Spalanie W Mieście', 'Typ nadwozia',
#        'Emisja CO2', 'Liczba drzwi', 'Liczba miejsc', 'Kolor', 'Rodzaj koloru',
#        'Kraj pochodzenia', 'Data pierwszej rejestracji w historii pojazdu',
#        'Numer rejestracyjny pojazdu', 'Zarejestrowany w Polsce', 'Tuning',
#        'Stan', 'VIN', 'Bezwypadkowy', 'Serwisowany w ASO', 'Leasing',
#        ' Pierwszy właściciel (od nowości)', 'Spalanie W Cyklu Mieszanym',
#        'Okres gwarancji producenta', 'lub do (przebieg km)',
#        'Możliwość finansowania', 'Faktura VAT', 'Uszkodzony', 'VAT marża',
#        'Gwarancja dealerska (w cenie)', 'Miesięczna rata', 'Opłata początkowa',
# ...

# %%
# Droping unhelpful columns
data = data.drop(['Oferta od', 'Pokaż oferty z numerem VIN', 'Liczba drzwi', 'Liczba miejsc', 'VIN'], axis=1)

# %%
data
# Out:
#                                     Nazwa     Cena Ma numer rejestracyjny  \
# 0                        BMW Seria 3 330d   21 900                    Tak
# 1             BMW Seria 3 328i Sport Line   77 600                    Tak
# 2     BMW Seria 3 320d xDrive Luxury Line   29 999                    Tak
# 3        BMW Seria 3 330d Touring M Sport   69 900                    NaN
# 4                             BMW Seria 3   58 500                    Tak
# ...                                   ...      ...                    ...
# 3513                     BMW Seria 3 318d  119 900                    Tak
# 3514                     BMW Seria 3 320d   46 000                    Tak
# 3515                   BMW Seria 3 330 Cd   39 000                    Tak
# 3516             BMW Seria 3 318d Touring   49 000                    NaN
# 3517                    BMW Seria 3 320Ci   15 500                    Tak
#
#      Marka pojazdu Model pojazdu                   Wersja  \
# ...

# %%
# Correcting the data
# data['Zarejestrowany w Polsce', 'Tuning',
#        'Stan', 'VIN', 'Bezwypadkowy', 'Serwisowany w ASO', 'Leasing',
#        ' Pierwszy właściciel (od nowości)', 'Spalanie W Cyklu Mieszanym',
#        'Okres gwarancji producenta', 'lub do (przebieg km)',
#        'Możliwość finansowania', 'Faktura VAT', 'Uszkodzony']
yes_fields = ['Ma numer rejestracyjny', 'Zarejestrowany w Polsce', 'Tuning', 'Bezwypadkowy', 'Serwisowany w ASO', 'Leasing',' Pierwszy właściciel (od nowości)', 
              'Możliwość finansowania', 'Faktura VAT', 'Uszkodzony']
data[yes_fields] = data[yes_fields].fillna(0)
data[yes_fields] = data[yes_fields].replace('Tak', 1)
data['Okres gwarancji producenta'] = data['Okres gwarancji producenta'].fillna(0)

# %%
data.head()
# Out:
#                                  Nazwa    Cena  Ma numer rejestracyjny  \
# 0                     BMW Seria 3 330d  21 900                       1
# 1          BMW Seria 3 328i Sport Line  77 600                       1
# 2  BMW Seria 3 320d xDrive Luxury Line  29 999                       1
# 3     BMW Seria 3 330d Touring M Sport  69 900                       0
# 4                          BMW Seria 3  58 500                       1
#
#   Marka pojazdu Model pojazdu                   Wersja  \
# 0           BMW       Seria 3                     330d
# 1           BMW       Seria 3          328i Sport Line
# 2           BMW       Seria 3  320d xDrive Luxury Line
# 3           BMW       Seria 3     330d Touring M Sport
# 4           BMW       Seria 3                      NaN
#
#                      Generacja  Rok produkcji    Przebieg Pojemność skokowa  \
# 0              E46 (1998-2007)           2003  436 000 km         2 993 cm3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3518 entries, 0 to 3517
# Data columns (total 45 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Nazwa                                          3518 non-null   object
#  1   Cena                                           3518 non-null   object
#  2   Ma numer rejestracyjny                         3518 non-null   int64
#  3   Marka pojazdu                                  3518 non-null   object
#  4   Model pojazdu                                  3518 non-null   object
#  5   Wersja                                         2605 non-null   object
#  6   Generacja                                      3477 non-null   object
#  7   Rok produkcji                                  3518 non-null   int64
#  8   Przebieg                                       3511 non-null   object
# ...
